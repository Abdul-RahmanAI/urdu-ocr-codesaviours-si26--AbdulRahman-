# %% [markdown]
# <a href="https://colab.research.google.com/github/Abdul-RahmanAI/urdu-ocr-codesaviours-si26--AbdulRahman-/blob/main/SI26_Week1_%5BAbdulRahman%5D.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import zipfile
with zipfile.ZipFile('/content/main.csv.zip', 'r') as zip_ref:
 zip_ref.extractall('/content/')

# %%
import pandas as pd
df = pd.read_csv('/content/main.csv')
df.head()
# Out:
#    Unnamed: 0  file_name                                               text
# 0           0     /0.png  پشاور،بنوں (نمائندہ جنگ،اے ایف پی) بنوں میں اق...
# 1           1     /1.png     اسکے ساتھ ملحقہ علاقے کے عوام نے بجلی و گیس \n
# 2           2    /10.png  نے بجلی وگیس کی لوڈشیڈنگ کیخلاف مظاہرہ کیا۔ مظ...
# 3           3   /100.png  نہیں آ یا۔ آخریہ کونسا مذہب ہے؟کیا اسلام کے نا...
# 4           4  /1000.png   ضرور ہے۔ انہوں نے کہا کہ میرا احمدیوں سے کوئی \n

# %%
import pandas as pd

# Read the original CSV
df = pd.read_csv('/content/main.csv')

# Keep only the required columns
labels = df[['file_name', 'text']]

# Rename the column
labels = labels.rename(columns={'file_name': 'image'})

# Save as labels.csv
labels.to_csv('/content/labels.csv', index=False, encoding='utf-8')

print("labels.csv created successfully!")
# Out:
# labels.csv created successfully!
